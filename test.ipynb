# %%
print('hello world')
for i in range(3):
    print(i)
# Out:
# hello world
# 0
# 1
# 2

# %% [markdown]
# # Markdown Cell
#
# *It* **really** is!

# %%
this is a syntax error
# Out:
#   File "<ipython-input-4-6c5185427360>", line 1
#     this is a syntax error
#                    ^
# SyntaxError: invalid syntax

# %%
from IPython.display import Image
Image('./PyDataNYC.jpg')
